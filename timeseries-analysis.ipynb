# %% [markdown]
# <a href="https://colab.research.google.com/github/b1ngster/solar-panel-analysis/blob/main/timeseries-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd

# %%
data = pd.read_excel('https://github.com/b1ngster/solar-panel-analysis/raw/main/SolarTrackers2018MiniProject.xlsx')
data
# Out:
#            Date and time Energy per inverter|IG 60(1) (# 1)  \
# 0           [dd.MM.yyyy]                              [kWh]
# 1    2018-01-01 00:00:00                               4.61
# 2    2018-01-02 00:00:00                               0.56
# 3    2018-01-03 00:00:00                               1.36
# 4    2018-01-04 00:00:00                               1.09
# ..                   ...                                ...
# 363  2018-12-29 00:00:00                               4.23
# 364  2018-12-30 00:00:00                               0.32
# 365  2018-12-31 00:00:00                               0.38
# 366  2019-01-01 00:00:00                              10.54
# 367                  NaN                              428.5
#
#     Energy per inverter|IG 60(2) (# 2) Total system  Unnamed: 4  Unnamed: 5  \
# 0                                [kWh]        [kWh]         NaN         NaN
# 1                                 3.56         8.17         NaN         NaN
# 2                                 0.64          1.2         NaN         NaN
# 3                                 1.21         2.58         NaN         NaN
# 4                                 1.21          2.3         NaN         NaN
# ..                                 ...          ...         ...         ...
# 363                               6.12        10.35         NaN         NaN
# 364                                0.3         0.62         NaN         NaN
# 365                               0.38         0.76         NaN         NaN
# 366                              11.11        21.65         NaN         NaN
# 367                                NaN          NaN         NaN         NaN
#
#         Month  Inverter 1  Inverter 2
# 0     January      159.28      138.10
# 1    February      428.50      382.29
# 2       March      329.51      352.73
# 3       April      561.41      507.45
# 4         May     1105.16     1125.31
# ..        ...         ...         ...
# 363       NaN         NaN         NaN
# 364       NaN         NaN         NaN
# 365       NaN         NaN         NaN
# 366       NaN         NaN         NaN
# 367       NaN         NaN         NaN
#
# [368 rows x 9 columns]
